# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
df=pd.read_csv('googleplaystore_updatedcopy.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs Price Content Rating  \
# 0         4.1     159                 19M      10,000+     0       Everyone
# 1         3.9     967                 14M     500,000+     0       Everyone
# 2         4.7   87510                8.7M   5,000,000+     0       Everyone
# 3         4.5  215644                 25M  50,000,000+     0           Teen
# 4         4.3     967                2.8M     100,000+     0       Everyone
# ...       ...     ...                 ...          ...   ...            ...
# 10836     4.5      38                 53M       5,000+     0       Everyone
# 10837     5.0       4                3.6M         100+     0       Everyone
# 10838     NaN       3                9.5M       1,000+     0       Everyone
# 10839     4.5     114  Varies with device       1,000+     0     Mature 17+
# 10840     4.5  398307                 19M  10,000,000+     0       Everyone
#
#                           Genres          Released         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design   Aughust 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                   1
# 10838                    Medical  January 20, 2017                   1
# 10839          Books & Reference  January 19, 2015  Varies with device
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10841 rows x 12 columns]

# %% [markdown]
# ## date clean up

# %%
# the spelling of August was wrong in the csv file
replacements = {
    'Augst': 'August',
    'Auguest': 'August',
    'Agust': 'August',
    'Aughust': 'August'
}

df['Released'] = df['Released'].str.replace('Aughust','August')

# %%
df['Released']=pd.to_datetime(df['Released'],format='%B %d, %Y',errors='coerce')
# yes so its fixed

# %% [markdown]
# ## cleaning the numeric value

# %% [markdown]
# ### FOR Installs column

# %%
df['Installs']=df['Installs'].str.replace('+','')
df['Installs']=df['Installs'].str.replace(',','')

# %% [markdown]
# ### for size column

# %%
df['Size']=df['Size'].str.replace('M','')
df
df2=df.copy()

# %% [markdown]
# # converting the required into numeric values

# %%
df2['Installs']=df2['Installs'].replace('Free',np.nan)
df2['Installs']=df2['Installs'].astype(float)
df2['Size']=df2['Size'].replace('Varies with device',np.nan)
df2['Size']=df2['Size'].str.replace('k','')
df2['Size']=df2['Size'].str.replace('+','')
df2['Size']=df2['Size'].str.replace(',','')
df2['Size']=df2['Size'].astype(float)

# %%
# converting review into integer
df2['Reviews']=df2['Reviews'].str.replace('M','')
df2['Reviews']=df2['Reviews'].astype(float)

# %%
df2['Price']=df2['Price'].str.replace('$','')
df2['Price']=df2['Price'].replace('Everyone',np.nan)
df2['Price']=df2['Price'].astype(float)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Price           10840 non-null  float64
#  7   Content Rating  10840 non-null  object
#  8   Genres          10841 non-null  object
#  9   Released        10526 non-null  datetime64[ns]
#  10  Current Ver     10833 non-null  object
#  11  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(6)
# memory usage: 1016.5+ KB

# %%
df2.to_csv('play_store.csv')
